# %%
import os
import subprocess
import re

# %%
person = r"\manue"

# %%
path_2 = r"C:\Users\Guilhem Leprince\repo"
path = r"C:\Users\guilhem.leprince\Documents\strava"
directory = path + r"\data" + person + r"\activities"

FIT_FILE = re.compile("\\d+.fit(?!.gz)")
GPX_FILE = re.compile("\\d+.gpx(?!.gz)")
CSV_FILE = re.compile("\\d+.csv")

# %%
list_of_fit_files=[]
list_of_gpx_files = []
list_of_raw_csv_files = []

for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f) and FIT_FILE.match(filename):
        list_of_fit_files.append(f)
    if os.path.isfile(f) and GPX_FILE.match(filename):
        list_of_gpx_files.append(f)

print("A total of "+str(len(list_of_fit_files)) + " fit files found in the directory : " + directory)
# Out:
# A total of 195 fit files found in the directory : C:\Users\guilhem.leprince\Documents\strava\data\manue\activities

# %%
# Use only when decoding fit file needed

c=1
l = len(list_of_fit_files)

for fit_file in list_of_fit_files:
    print("["+str(c)+"/"+str(l)+"] processing :" + fit_file.split("activities")[1])
    subprocess.call("java -jar \""+ path + "\\sdk\\java\\FitCSVTool.jar\" \"" + fit_file +"\"")
    c+=1

for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    if os.path.isfile(f) and CSV_FILE.match(filename):
        list_of_raw_csv_files.append(f)

print("A total of " + str(len(list_of_raw_csv_files)) + " csv file created")
# Out:
# [1/195] processing :\2062380536.fit
# [2/195] processing :\2071986615.fit
# [3/195] processing :\2083959364.fit
# [4/195] processing :\2095695676.fit
# [5/195] processing :\2099314939.fit
# [6/195] processing :\2106979809.fit
# [7/195] processing :\2110703651.fit
# [8/195] processing :\2113573762.fit
# [9/195] processing :\2163025334.fit
# [10/195] processing :\2166025078.fit
# [11/195] processing :\2194127721.fit
# [12/195] processing :\2197623650.fit
# [13/195] processing :\2206037630.fit
# [14/195] processing :\2212579279.fit
# [15/195] processing :\2229280510.fit
# [16/195] processing :\2270227900.fit
# [17/195] processing :\2279375143.fit
# [18/195] processing :\2286012912.fit
# [19/195] processing :\2303797667.fit
# [20/195] processing :\2314574377.fit
# [21/195] processing :\2317179433.fit
# [22/195] processing :\2327122396.fit
# [23/195] processing :\2329459962.fit
# [24/195] processing :\2337316605.fit
# [25/195] processing :\2359814819.fit
# [26/195] processing :\2361882201.fit
# [27/195] processing :\2406641927.fit
# [28/195] processing :\2447538558.fit
# [29/195] processing :\2483067882.fit
# [30/195] processing :\2494214145.fit
# [31/195] processing :\2522621115.fit
# [32/195] processing :\2562305295.fit
# [33/195] processing :\2565937290.fit
# [34/195] processing :\2626664300.fit
# [35/195] processing :\2626664682.fit
# [36/195] processing :\2628814973.fit
# [37/195] processing :\2665044124.fit
# [38/195] processing :\2685262275.fit
# [39/195] processing :\2739373400.fit
# [40/195] processing :\2751174022.fit
# [41/195] processing :\2783777433.fit
# [42/195] processing :\2838485516.fit
# [43/195] processing :\2850983650.fit
# [44/195] processing :\2855359158.fit
# [45/195] processing :\2865338398.fit
# [46/195] processing :\2873671990.fit
# [47/195] processing :\2873691136.fit
# [48/195] processing :\2897861279.fit
# [49/195] processing :\2911789114.fit
# [50/195] processing :\2916989744.fit
# [51/195] processing :\2952812776.fit
# [52/195] processing :\2962918969.fit
# [53/195] processing :\2982685294.fit
# [54/195] processing :\3000580796.fit
# [55/195] processing :\3003112259.fit
# [56/195] processing :\3028747576.fit
# [57/195] processing :\3030259431.fit
# [58/195] processing :\3155428583.fit
# [59/195] processing :\3181588465.fit
# [60/195] processing :\3217179019.fit
# [61/195] processing :\3316847909.fit
# [62/195] processing :\3329257771.fit
# [63/195] processing :\3342700664.fit
# [64/195] processing :\3357245551.fit
# [65/195] processing :\3360477949.fit
# [66/195] processing :\3709136195.fit
# [67/195] processing :\3743757395.fit
# [68/195] processing :\3760891446.fit
# [69/195] processing :\3880368083.fit
# [70/195] processing :\3902414557.fit
# [71/195] processing :\3923803257.fit
# [72/195] processing :\3952973052.fit
# [73/195] processing :\4017409468.fit
# [74/195] processing :\4017411041.fit
# [75/195] processing :\4058018749.fit
# [76/195] processing :\4062636638.fit
# [77/195] processing :\4155338376.fit
# [78/195] processing :\4166854634.fit
# [79/195] processing :\4186875922.fit
# [80/195] processing :\4192434497.fit
# [81/195] processing :\4340274776.fit
# [82/195] processing :\4360082076.fit
# [83/195] processing :\4390065639.fit
# [84/195] processing :\4441825474.fit
# [85/195] processing :\4621535629.fit
# [86/195] processing :\4642146498.fit
# [87/195] processing :\4711860853.fit
# [88/195] processing :\4743292149.fit
# [89/195] processing :\4774442451.fit
# [90/195] processing :\4794939179.fit
# [91/195] processing :\4799247411.fit
# [92/195] processing :\4808607160.fit
# [93/195] processing :\4816623206.fit
# [94/195] processing :\4952735821.fit
# [95/195] processing :\5065675859.fit
# [96/195] processing :\5071258745.fit
# [97/195] processing :\5101820472.fit
# [98/195] processing :\5207667221.fit
# [99/195] processing :\5221073446.fit
# [100/195] processing :\5245093323.fit
# [101/195] processing :\5317647889.fit
# [102/195] processing :\5358336304.fit
# [103/195] processing :\5433854356.fit
# [104/195] processing :\5504544190.fit
# [105/195] processing :\5535117679.fit
# [106/195] processing :\5546942652.fit
# [107/195] processing :\5582172482.fit
# [108/195] processing :\5641615254.fit
# [109/195] processing :\5652965500.fit
# [110/195] processing :\5664906679.fit
# [111/195] processing :\5686461077.fit
# [112/195] processing :\5989878023.fit
# [113/195] processing :\6017325857.fit
# [114/195] processing :\6113686746.fit
# [115/195] processing :\6113690537.fit
# [116/195] processing :\6113695011.fit
# [117/195] processing :\6113698348.fit
# [118/195] processing :\6113701116.fit
# [119/195] processing :\6131307284.fit
# [120/195] processing :\6146928836.fit
# [121/195] processing :\6158649376.fit
# [122/195] processing :\6213479373.fit
# [123/195] processing :\6239071638.fit
# [124/195] processing :\6244571794.fit
# [125/195] processing :\6275420152.fit
# [126/195] processing :\6317661756.fit
# [127/195] processing :\6388116607.fit
# [128/195] processing :\6475634566.fit
# [129/195] processing :\6475642256.fit
# [130/195] processing :\6477235124.fit
# [131/195] processing :\6519307121.fit
# [132/195] processing :\6548057655.fit
# [133/195] processing :\6548058868.fit
# [134/195] processing :\6548064098.fit
# [135/195] processing :\6710708758.fit
# [136/195] processing :\6714970002.fit
# [137/195] processing :\6840979007.fit
# [138/195] processing :\6844564087.fit
# [139/195] processing :\6854689567.fit
# [140/195] processing :\6859222904.fit
# [141/195] processing :\6871607822.fit
# [142/195] processing :\6871611712.fit
# [143/195] processing :\6876266094.fit
# [144/195] processing :\6887330915.fit
# [145/195] processing :\6949112450.fit
# [146/195] processing :\6985963227.fit
# [147/195] processing :\6985971499.fit
# [148/195] processing :\7025408088.fit
# [149/195] processing :\7025415303.fit
# [150/195] processing :\7131080219.fit
# [151/195] processing :\7138398259.fit
# [152/195] processing :\7160636675.fit
# [153/195] processing :\7160638740.fit
# [154/195] processing :\7163593692.fit
# [155/195] processing :\7186938223.fit
# [156/195] processing :\7195795886.fit
# [157/195] processing :\7195796648.fit
# [158/195] processing :\7200979338.fit
# [159/195] processing :\7247834787.fit
# [160/195] processing :\7253651574.fit
# [161/195] processing :\7292148075.fit
# [162/195] processing :\7333000445.fit
# [163/195] processing :\7333009606.fit
# [164/195] processing :\7400973789.fit
# [165/195] processing :\7407014226.fit
# [166/195] processing :\7417741586.fit
# [167/195] processing :\7417745407.fit
# [168/195] processing :\7429005937.fit
# [169/195] processing :\7434805642.fit
# [170/195] processing :\7441803893.fit
# [171/195] processing :\7450869560.fit
# [172/195] processing :\7514769276.fit
# [173/195] processing :\7527194982.fit
# [174/195] processing :\7527205241.fit
# [175/195] processing :\7732339889.fit
# [176/195] processing :\7732346270.fit
# [177/195] processing :\7732350331.fit
# [178/195] processing :\7772541615.fit
# [179/195] processing :\7813262703.fit
# [180/195] processing :\7847968377.fit
# [181/195] processing :\8072345583.fit
# [182/195] processing :\8099882045.fit
# [183/195] processing :\8109700897.fit
# [184/195] processing :\8117120062.fit
# [185/195] processing :\8124582354.fit
# [186/195] processing :\8135241242.fit
# [187/195] processing :\8147299272.fit
# [188/195] processing :\8184935877.fit
# [189/195] processing :\8274352012.fit
# [190/195] processing :\8279264048.fit
# [191/195] processing :\8321365511.fit
# [192/195] processing :\8366014777.fit
# [193/195] processing :\8366018645.fit
# [194/195] processing :\8405186685.fit
# [195/195] processing :\8409171482.fit
# A total of 195 csv file created
