# %%
import pandas as pd

# %%
FILE_PATH = "data_example/raw_csv/"
FILENAME = "8279264048.csv"

# %%
raw_data=pd.read_csv(FILE_PATH + FILENAME)

# %%
raw_data[raw_data["Local Number"]==12].tail(20)
# Out:
#       Type  Local Number Message    Field 1     Value 1 Units 1       Field 2  \
# 2198  Data            12  record  timestamp  1031231332       s  position_lat
# 2199  Data            12  record  timestamp  1031231350       s  position_lat
# 2200  Data            12  record  timestamp  1031231364       s  position_lat
# 2201  Data            12  record  timestamp  1031231365       s  position_lat
# 2202  Data            12  record  timestamp  1031231382       s  position_lat
# 2203  Data            12  record  timestamp  1031231405       s  position_lat
# 2205  Data            12  record  timestamp  1031231413       s  position_lat
# 2206  Data            12  record  timestamp  1031231427       s  position_lat
# 2207  Data            12  record  timestamp  1031231438       s  position_lat
# 2208  Data            12  record  timestamp  1031231441       s  position_lat
# 2209  Data            12  record  timestamp  1031231446       s  position_lat
# 2210  Data            12  record  timestamp  1031231451       s  position_lat
# 2211  Data            12  record  timestamp  1031231467       s  position_lat
# 2212  Data            12  record  timestamp  1031231468       s  position_lat
# 2213  Data            12  record  timestamp  1031231473       s  position_lat
# 2214  Data            12  record  timestamp  1031231477       s  position_lat
# 2215  Data            12  record  timestamp  1031231479       s  position_lat
# 2216  Data            12  record  timestamp  1031231480       s  position_lat
# 2217  Data            12  record  timestamp  1031231481       s  position_lat
# 2219  Data            12  record  timestamp  1031231482       s  position_lat
#
#         Value 2      Units 2        Field 3  ...  Field 42 Value 42 Units 42  \
# 2198  509997856  semicircles  position_long  ...       NaN      NaN      NaN
# 2199  510000195  semicircles  position_long  ...       NaN      NaN      NaN
# 2200  510001678  semicircles  position_long  ...       NaN      NaN      NaN
# 2201  510001799  semicircles  position_long  ...       NaN      NaN      NaN
# 2202  510003037  semicircles  position_long  ...       NaN      NaN      NaN
# 2203  510003206  semicircles  position_long  ...       NaN      NaN      NaN
# 2205  510003063  semicircles  position_long  ...       NaN      NaN      NaN
# 2206  510003180  semicircles  position_long  ...       NaN      NaN      NaN
# 2207  510003031  semicircles  position_long  ...       NaN      NaN      NaN
# 2208  510002723  semicircles  position_long  ...       NaN      NaN      NaN
# 2209  510002841  semicircles  position_long  ...       NaN      NaN      NaN
# 2210  510003388  semicircles  position_long  ...       NaN      NaN      NaN
# 2211  510004679  semicircles  position_long  ...       NaN      NaN      NaN
# 2212  510004975  semicircles  position_long  ...       NaN      NaN      NaN
# 2213  510006815  semicircles  position_long  ...       NaN      NaN      NaN
# 2214  510007967  semicircles  position_long  ...       NaN      NaN      NaN
# 2215  510008599  semicircles  position_long  ...       NaN      NaN      NaN
# 2216  510008827  semicircles  position_long  ...       NaN      NaN      NaN
# 2217  510008920  semicircles  position_long  ...       NaN      NaN      NaN
# 2219  510009001  semicircles  position_long  ...       NaN      NaN      NaN
#
#       Field 43 Value 43 Units 43 Field 44 Value 44 Units 44  Unnamed: 135
# 2198       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2199       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2200       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2201       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2202       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2203       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2205       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2206       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2207       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2208       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2209       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2210       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2211       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2212       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2213       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2214       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2215       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2216       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2217       NaN      NaN      NaN      NaN      NaN      NaN           NaN
# 2219       NaN      NaN      NaN      NaN      NaN      NaN           NaN
#
# [20 rows x 136 columns]

# %%
raw_data.describe()
# Out:
#        Local Number       Value 3       Value 4       Value 6       Value 8  \
# count   2234.000000  2.232000e+03  2.230000e+03  2.155000e+03   2117.000000
# mean      11.818263  3.554219e+06  6.349404e+03  1.804062e+03    158.335737
# std        1.468312  3.432629e+07  6.851037e+04  5.477923e+04    431.965524
# min        0.000000  0.000000e+00  0.000000e+00  0.000000e+00      0.000000
# 25%       12.000000  2.293096e+06  1.480490e+03  0.000000e+00    114.000000
# 50%       12.000000  2.301745e+06  3.739775e+03  6.250000e-01    127.000000
# 75%       12.000000  2.346637e+06  6.820095e+03  9.240000e-01    143.000000
# max       15.000000  1.031239e+09  2.286019e+06  2.285909e+06  15724.156000
#
#             Value 9      Value 10      Value 11      Value 12  Units 13  ...  \
# count  2.093000e+03  2.092000e+03  2.091000e+03  2.091000e+03       0.0  ...
# mean   2.437114e+05  1.190784e+03  4.898831e+05  2.281146e+03       NaN  ...
# std    1.114791e+07  5.428256e+04  1.576616e+07  7.378598e+04       NaN  ...
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       NaN  ...
# 25%    0.000000e+00  0.000000e+00  2.005000e+03  0.000000e+00       NaN  ...
# 50%    4.400000e+01  0.000000e+00  2.246200e+03  6.340000e-01       NaN  ...
# 75%    5.900000e+01  0.000000e+00  2.350100e+03  9.140000e-01       NaN  ...
# max    5.100091e+08  2.482788e+06  5.100091e+08  2.482788e+06       NaN  ...
#
#        Units 40  Value 41  Units 41  Value 42  Units 42  Value 43  Units 43  \
# count       0.0       3.0       0.0       2.0       0.0       1.0       0.0
# mean        NaN       1.0       NaN       1.0       NaN       1.0       NaN
# std         NaN       0.0       NaN       0.0       NaN       NaN       NaN
# min         NaN       1.0       NaN       1.0       NaN       1.0       NaN
# 25%         NaN       1.0       NaN       1.0       NaN       1.0       NaN
# 50%         NaN       1.0       NaN       1.0       NaN       1.0       NaN
# 75%         NaN       1.0       NaN       1.0       NaN       1.0       NaN
# max         NaN       1.0       NaN       1.0       NaN       1.0       NaN
#
#        Value 44  Units 44  Unnamed: 135
# count       1.0       0.0           0.0
# mean        1.0       NaN           NaN
# std         NaN       NaN           NaN
# min         1.0       NaN           NaN
# 25%         1.0       NaN           NaN
# 50%         1.0       NaN           NaN
# 75%         1.0       NaN           NaN
# max         1.0       NaN           NaN
#
# [8 rows x 51 columns]

# %%
raw_data[raw_data["Local Number"]==12]["Value 4"].plot().grid()

# %% [markdown]
# Dataframe final : record 12 + record 14
# record 14 : ajouter des colonnes lat lon à null
# record 12 supprimer colonnes inutiles
# matcher les deux df ssur le df final et réindexer sur le timestamp !

# %%
raw_data_12 = raw_data[raw_data["Local Number"]==12][["Local Number",
                                                      "Value 1","Value 2","Value 3","Value 4","Value 5","Value 6",
                                                      "Value 7","Value 8","Value 9","Value 10","Value 11","Value 12"]]
raw_data_12=raw_data_12.rename(columns={"Local Number":"datatype", "Value 1": "time", "Value 2": "lat","Value 3": "lon",
                                        "Value 4": "dist", "Value 5": "alti", "Value 6": "spd", "Value 7": "quid",
                                        "Value 8" :"bpm", "Value 9": "cad", "Value 10": "fraq", "Value 11": "alti_corr",
                                        "Value 12": "spd_corr"})

# %%
raw_data_12.head(10)
# Out:
#     datatype        time        lat        lon   dist                alti  \
# 27        12           1          1        1.0   1.00                   1
# 28        12  1031213441  510009083  2286019.0   0.00  1833.8000000000002
# 29        12  1031213442  510009020  2286075.0   0.70  1833.8000000000002
# 30        12  1031213447  510008603  2286536.0   5.70  1833.8000000000002
# 31        12  1031213451  510008276  2286858.0   9.49              1833.6
# 32        12  1031213456  510007714  2287092.0  14.91              1833.6
# 33        12  1031213460  510007488  2287258.0  17.25              1833.4
# 34        12  1031213477  510007424  2287643.0  21.89  1830.8000000000002
# 35        12  1031213481  510007302  2287616.0  22.50              1830.6
# 36        12  1031213486  510007290  2287619.0  22.71              1830.4
#
#       spd quid    bpm   cad  fraq  alti_corr  spd_corr
# 27  1.000    1    1.0   1.0   1.0        NaN       NaN
# 28  0.000  300  100.0  59.0   0.0     1833.8     0.000
# 29  0.000  300   97.0  59.0   0.0     1833.8     0.000
# 30  0.896  300  100.0  59.0   0.0     1833.8     0.896
# 31  1.045  300  100.0   0.0   0.0     1833.6     1.045
# 32  1.017  300  106.0   0.0   0.0     1833.6     1.017
# 33  0.728  300  109.0   0.0   0.0     1833.4     0.728
# 34  0.000  300  106.0   0.0   0.0     1830.8     0.000
# 35  0.000  300  103.0   0.0   0.0     1830.6     0.000
# 36  0.000  300   86.0   0.0   0.0     1830.4     0.000

# %%
raw_data_14 = raw_data[raw_data["Local Number"]==14][["Local Number",
                                                      "Value 1","Value 2","Value 3","Value 4","Value 5","Value 6",
                                                      "Value 7","Value 8"]]
raw_data_14 = raw_data_14.rename(columns={"Local Number":"datatype", "Value 1": "time", "Value 2": "dist","Value 3": "alt",
                                        "Value 4": "quid", "Value 5": "bpm", "Value 6": "cad", "Value 7": "frac",
                                        "Value 8" :"alti_corr"})

# %%
raw_data_14["lat"]=""
raw_data_14["lon"]=""
raw_data_14["spd"]=""
raw_data_14["spd_corr"]=""

# %%
raw_data_14.head()
# Out:
#      datatype        time    dist     alt   quid  bpm   cad frac  alti_corr  \
# 103        14           1       1     1.0    1.0    1   1.0    1        NaN
# 104        14  1031213970  311.16  1840.2  300.0  122   0.0  0.0     1840.2
# 105        14  1031213976  311.16  1840.2  300.0  121   0.0  0.0     1840.2
# 106        14  1031213977  311.16  1840.2  300.0  120   0.0  0.0     1840.2
# 109        14  1031213981  318.28  1842.6  300.0  119  59.0  0.0     1842.6
#
#     lat lon spd spd_corr
# 103
# 104
# 105
# 106
# 109

# %%
df=raw_data_12.append(raw_data_14)
df = df.set_index("time")

# %%
df.describe()
# Out:
#           datatype          cad         fraq    alti_corr          alt
# count  2097.000000  2097.000000  2076.000000  2095.000000    21.000000
# mean     12.020029    33.091082     0.103324  2177.693938  1778.600000
# std       0.199186    29.485891     0.203093   205.734989   407.909627
# min      12.000000     0.000000     0.000000  1800.600000     1.000000
# 25%      12.000000     0.000000     0.000000  2002.200000  1842.600000
# 50%      12.000000    44.000000     0.000000  2246.000000  1885.600000
# 75%      12.000000    59.000000     0.000000  2349.900000  1885.600000
# max      14.000000    85.000000     1.000000  2473.800000  1885.600000
